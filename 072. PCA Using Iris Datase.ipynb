# %%
# ************************ PCA in Python Using the Iris Dataset **********************************
import pandas as pd 
import numpy as np 
from sklearn.decomposition import PCA 
from sklearn import preprocessing 
import matplotlib.pyplot as plt

url = "D:/iris.data"
df = pd.read_csv(url, names=['sepal length', 'sepal width', 'petal length', 'petal width', 'target'])

# %%
x = df.loc[:,['sepal length']]

# %%
y = df.loc[:,['petal length']]

# %%
plt.scatter(x,y)

# %%
ax = df.plot.scatter(x='sepal length', y='petal width', c="Red", title="Kindson")

# %%
plt.scatter(x='sepal length', y='petal width')

# %%
from sklearn.preprocessing import StandardScaler

features = ['sepal length', 'sepal width', 'petal length', 'petal width']

x = df.loc[:, features].values

y = df.loc[:, ['target']].values

# %%
pca = PCA(n_components=4)

principalComponents = pca.fit_transform(x)

principalDataframe = pd.DataFrame(data = principalComponents, columns = ['PC1', 'PC2', 'PC3', 'PC4'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-89981262f3d5> in <module>()
# ----> 1 pca = PCA(n_components=4)
#       2
#       3 principalComponents = pca.fit_transform(x)
#       4
#       5 principalDataframe = pd.DataFrame(data = principalComponents, columns = ['PC1', 'PC2', 'PC3', 'PC4'])
#
# NameError: name 'PCA' is not defined

# %%
principalDataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8480f9bcc1b0> in <module>()
# ----> 1 principalDataframe
#
# NameError: name 'principalDataframe' is not defined

# %%
percent_variance = np.round(pca.explained_variance_ratio_* 100, decimals =2)
columns = ['PC1', 'PC2', 'PC3', 'PC4']
plt.bar(x= range(1,5), height=percent_variance, tick_label=columns)
plt.ylabel('Percentate of Variance Explained')
plt.xlabel('Principal Component')
plt.title('PCA Scree Plot')
plt.show()

# %%
targetDataframe = df[['target']]

newDataframe = pd.concat([principalDataframe, targetDataframe],axis = 1)

# %%
plt.scatter(principalDataframe.PC1, principalDataframe.PC2)
plt.title('PC1 against PC2')
plt.xlabel('PC1')
plt.ylabel('PC2')
# Out:
# Text(0,0.5,'PC2')

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')

ax.set_title('Plot of PC1 vs PC2', fontsize = 20)

targets = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

colors = ['r', 'g', 'b']

for target, color in zip(targets,colors):
    indicesToKeep = newDataframe['target'] == target
    ax.scatter(newDataframe.loc[indicesToKeep, 'PC1']
               , newDataframe.loc[indicesToKeep, 'PC2']
               , c = color
               , s = 50)
    
ax.legend(targets)
ax.grid()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.72770452, 0.23030523])
